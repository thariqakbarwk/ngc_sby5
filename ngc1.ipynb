# %% [markdown]
# # Objetcive

# %% [markdown]
# # Task

# %% [markdown]
# ## Task 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Assign Customer List
customer_id = []
# Check how many data list
len(customer_id)
# Out:
# 0

# %% [markdown]
# ## Task 2
